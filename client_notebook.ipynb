# %%
import requests

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/libfun/Documents/odessa_ds/titanic/test.csv')

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
import json

# %%
df.iloc[0].to_json()
# Out:
# '{"PassengerId":892,"Pclass":3,"Name":"Kelly, Mr. James","Sex":"male","Age":34.5,"SibSp":0,"Parch":0,"Ticket":"330911","Fare":7.8292,"Cabin":null,"Embarked":"Q"}'

# %%
r._content
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"\n  "http://www.w3.org/TR/html4/loose.dtd">\n<html>\n  <head>\n    <title>ValueError: dictionary update sequence element #0 has length 1; 2 is required // Werkzeug Debugger</title>\n    <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css"\n        type="text/css">\n    <!-- We need to make sure this has a favicon so that the debugger does\n         not by accident trigger a request to /favicon.ico which might\n         change the application state. -->\n    <link rel="shortcut icon"\n        href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">\n    <script src="?__debugger__=yes&amp;cmd=resource&amp;f=jquery.js"></script>\n    <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>\n    <script type="text/javascript">\n      var TRACEBACK = 139803843730400,\n          CONSOLE_MODE = false,\n          EVALEX = true,\n          EVALEX_TRUSTED = false,\n          SECR
# ...

# %%
r.__dir__()
# Out:
# ['_content',
#  '_content_consumed',
#  '_next',
#  'status_code',
#  'headers',
#  'raw',
#  'url',
#  'encoding',
#  'history',
#  'reason',
#  'cookies',
#  'elapsed',
#  'request',
#  'connection',
#  '__module__',
#  '__doc__',
#  '__attrs__',
#  '__init__',
#  '__enter__',
#  '__exit__',
#  '__getstate__',
#  '__setstate__',
#  '__repr__',
#  '__bool__',
#  '__nonzero__',
#  '__iter__',
#  'ok',
#  'is_redirect',
#  'is_permanent_redirect',
#  'next',
#  'apparent_encoding',
#  'iter_content',
#  'iter_lines',
#  'content',
#  'text',
#  'json',
#  'links',
#  'raise_for_status',
#  'close',
#  '__dict__',
#  '__weakref__',
#  '__hash__',
#  '__str__',
#  '__getattribute__',
#  '__setattr__',
#  '__delattr__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__new__',
#  '__reduce_ex__',
#  '__reduce__',
#  '__subclasshook__',
#  '__init_subclass__',
#  '__format__',
#  '__sizeof__',
#  '__dir__',
#  '__class__']

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
{"data": [df.iloc[i].to_dict()]}
# Out:
# {'data': [{'Age': 34.5,
#    'Cabin': nan,
#    'Embarked': 'Q',
#    'Fare': 7.8292,
#    'Name': 'Kelly, Mr. James',
#    'Parch': 0,
#    'PassengerId': 892,
#    'Pclass': 3,
#    'Sex': 'male',
#    'SibSp': 0,
#    'Ticket': '330911'}]}

# %%
json.dumps({"data": [df.iloc[i].to_dict()]})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-ae1b71a4f6a2> in <module>()
# ----> 1 json.dumps({"data": [df.iloc[i].to_dict()]})
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
# ...

# %%
df.iloc[i].Age.dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
for i in range(len(df)):
    json_r = {'data': [{'Age': df.iloc[i].Age,
                       'Cabin': df.iloc[i].Cabin,
                       'Embarked': df.iloc[i].Embarked,
                       'Fare': df.iloc[i].Fare,
                       'Name': df.iloc[i].Name,
                       'Parch': int(df.iloc[i].Parch),
                       'PassengerId': int(df.iloc[i].PassengerId),
                       'Pclass': int(df.iloc[i].Pclass),
                       'Sex': df.iloc[i].Sex,
                       'SibSp': int(df.iloc[i].SibSp),
                       'Ticket': df.iloc[i].Ticket}]}
    r = requests.post('http://54.209.150.91:6007/script', 
                      json=json_r)
    print(r.json())
    # break
# Out:
# {'result': [[0.6738123649681615, 0.32618763503183845]]}
# {'result': [[0.5092628028761453, 0.49073719712385466]]}
# {'result': [[0.5796855181548068, 0.42031448184519316]]}
# {'result': [[0.5051728973549385, 0.4948271026450615]]}
# {'result': [[0.6669988312411119, 0.333001168758888]]}
# {'result': [[0.5051728973549385, 0.4948271026450615]]}
# {'result': [[0.6723747926984671, 0.32762520730153283]]}
# {'result': [[0.8154837166785298, 0.1845162833214702]]}
# {'result': [[0.5298954169022289, 0.47010458309777114]]}
# {'result': [[0.7003826897138495, 0.29961731028615046]]}
# {'result': [[0.4634123211968063, 0.5365876788031937]]}
# {'result': [[0.7423291069208642, 0.2576708930791359]]}
# {'result': [[0.7501841010619825, 0.24981589893801742]]}
# {'result': [[0.7822700393696882, 0.21772996063031175]]}
# {'result': [[0.8410555088267055, 0.1589444911732945]]}
# {'result': [[0.7592263310981544, 0.2407736689018456]]}
# {'result': [[0.6670887243429701, 0.33291127565702994]]}
# ...
